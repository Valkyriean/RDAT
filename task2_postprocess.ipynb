# %% [markdown]
# Code for process hashtags:

# %%
rumour = {}
nonrumour = {}
with open("output/hashtags.csv", "r") as f:
    f.readline()
    for line in f.readlines():
        line = line.strip().split(',')
        tag = line[0]
        nonrumour_count = int(line[-2])
        rumour_count = int(line[-1])
        tag = tag.lower()
        # tag = re.sub(r'[^\w\s]', '', tag)
        tag = ''.join(ch for ch in tag if ch.isalnum())
        tag = tag.replace('ー','')
        nonrumour[tag] = nonrumour.get(tag, 0) + nonrumour_count
        rumour[tag] = rumour.get(tag, 0) + rumour_count
    nonrumour = {k: v for k, v in sorted(nonrumour.items(), key=lambda item: item[1],reverse=True)}
    rumour = {k: v for k, v in sorted(rumour.items(), key=lambda item: item[1],reverse=True)}
    print(nonrumour)
    f = open("output/hashtags_nonrumour.csv", 'w')
    f.write("")
    f.close()
    f = open("output/hashtags_rumour.csv", 'w')
    f.write("")
    f.close()
    with open("output/hashtags_nonrumour.csv", 'a') as w:
        for k,v in nonrumour.items():
            w.write(f"{k},{v}\n")
    with open("output/hashtags_rumour.csv", 'a') as w:
        for k,v in rumour.items():
            w.write(f"{k},{v}\n")
# Out:
# {'covid19': 2062, 'coronavirus': 951, 'breaking': 82, 'stayhome': 39, 'china': 38, 'coronaviruspandemic': 32, 'covid': 31, 'cdnpoli': 30, 'lockdown': 29, 'stayhomesavelives': 24, 'socialdistancing': 21, 'staysafe': 21, 'covid19ph': 18, 'stayalert': 18, 'stayathome': 17, 'indiafightscorona': 16, 'sarscov2': 16, 'txlege': 16, 'covid2019': 15, 'auspol': 15, 'onpoli': 14, 'pandemic': 13, 'takeresponsibility': 13, 'wuhan': 13, 'watch': 13, 'blacklivesmatter': 12, 'maga': 12, 'covid19nigeria': 11, 'india': 11, 'covid19india': 11, 'florida': 11, 'ridge': 11, 'coronavirussa': 11, 'marr': 11, 'hydroxychloroquine': 11, 'covidiots': 10, 'ppe': 10, 'familiesfirst': 10, 'trump': 9, 'nhs': 9, 'coronavirusoutbreak': 9, 'coronavirusinsa': 9, 'texas': 8, 'pmqs': 8, 'coronaviruslockdown': 8, 'oann': 8, 'flattenthecurve': 8, 'corona': 8, 'ccpvirus': 8, 'covid19insa': 8, 'wearamask': 8, 'komeshacorona': 8, 'togetherathome': 8, 'italy': 7, 'covid19uk': 7, 'staysafeug': 6, 'gapol': 6, 'sabcnews': 6, 'who': 6, 'youractionssavelives': 6, 'covid19pandemic': 6, 'covid19sa': 6, 'newsnight': 6, 'crushthecurve': 6, 'coronavirusuk': 6, 'coronaupdate': 6, 'gmb': 6, 'arizona': 6, 'inthistogetherohio': 6, 'foxnews': 6, '': 5, '
': 3, 'mondaythoughts': 3, 'phdchat': 3, 'ppp': 3, 'flatteningthecurve': 3, 'chinesevirus': 3, 'mlb': 3, 'abbottbetrayedtexas': 2, 'california': 2, 'educationministergoeslive': 2, 'islamophobiainindia': 2, 'mondaymotivaton': 2, 'bsl': 2, 'jeremyvine': 2, 'tx': 2, 'africans': 2, 'bhnasional': 2, 'seniors': 2, 'handhygiene': 2, 'r4today': 2, 'opinion': 2, 'tips': 2, 'nasa': 2, 'obamagate': 2, 'savelives': 2, 'wba': 2, 'spreadcalmnotfear': 2, 'coronavirusnewyork': 2, 'buharitormentor': 2, 'nationallottery': 2, 'smallbusiness': 2, 'maskupwa': 2, 'solicitorchat': 2, 'coronavirusaustralia': 2, 'spain': 2, 'navajonation': 2, 'fleabag': 2, 'meded': 2, 'apfightscorona': 2, 'swasari': 2, 'dominiccummings':  ...

# %% [markdown]
# Code for 5 number statistic for user characteristic

# %%
import pandas as pd
import matplotlib.pyplot as plt

pmn = pd.read_csv("output/public_metrics_nonrumour.csv")
pmr = pd.read_csv("output/public_metrics_rumour.csv")
# print(pmn.describe())
# print(pmr.describe())

# fig1, ax1 = plt.subplots()
# ax1.set_title('Basic Plot')
# ax1.boxplot(pmn.loc[3])
# plt.hist(pmn.loc[1])
print("followers_count")
# a1 = pd.DataFrame([pmn["followers_count"], pmr["followers_count"]])
plt.boxplot([pmn["followers_count"], pmr["followers_count"]],showfliers=False,labels=["nonrumour", "rumour"])
plt.show()
plt.boxplot([pmn["following_count"], pmr["following_count"]],showfliers=False,labels=["nonrumour", "rumour"])
plt.show()
plt.boxplot([pmn["tweet_count"], pmr["tweet_count"]],showfliers=False,labels=["nonrumour", "rumour"])
plt.show()
plt.boxplot([pmn["listed_count"], pmr["listed_count"]],showfliers=False,labels=["nonrumour", "rumour"])
plt.show()
# Out:
# followers_count

# %%
sn = pd.read_csv("output/sentiment_nonrumour.csv")
sr = pd.read_csv("output/sentiment_rumour.csv")
print(sn)
plt.boxplot([sn["compound"],sr["compound"]],showfliers=True, labels=["nonrumour", "rumour"])
plt.show()
# Out:
#          neg    neu    pos  compound
# 0      0.098  0.837  0.065   -0.1280
# 1      0.333  0.667  0.000   -0.6705
# 2      0.170  0.716  0.114   -0.3254
# 3      0.041  0.710  0.249    0.9136
# 4      0.068  0.878  0.055   -0.1725
# ...      ...    ...    ...       ...
# 11952  0.170  0.716  0.113    0.0258
# 11953  0.046  0.858  0.096    0.3400
# 11954  0.000  1.000  0.000    0.0000
# 11955  0.000  1.000  0.000    0.0000
# 11956  0.115  0.769  0.115    0.0000
#
# [11957 rows x 4 columns]
